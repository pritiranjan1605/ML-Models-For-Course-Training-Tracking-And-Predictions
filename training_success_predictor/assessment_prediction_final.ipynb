# %%
import pandas as pd
import numpy as np
import json
import time
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

print("All libraries imported successfully")
# Out:
# All libraries imported successfully

# %%
# Load training data
df_train_original = pd.read_csv('Employee_training.csv')
print(f"Training data loaded: {len(df_train_original)} records")
print(f"   Mean Assessment_Score: {df_train_original['Assessment_Score'].mean():.2f}")

# Load test data from JSON files
test_data_list = []
test_files = {
    'bench_test_data_unique.json': 50,
    'bench_test_data_500.json': 500,
    'bench_test_data_1000.json': 1000
}

for filepath, expected_count in test_files.items():
    try:
        with open(filepath, 'r') as f:
            test_json = json.load(f)
        test_data_list.extend(test_json)
        print(f"Loaded {filepath}: {len(test_json)} records")
    except:
        print(f"Could not load {filepath}")

df_test_data = pd.DataFrame(test_data_list)
print(f"\nTotal test data collected: {len(df_test_data)} records")
print(f"   Mean Assessment_Score: {df_test_data['Assessment_Score'].mean():.2f}")
# Out:
# Training data loaded: 1299 records
#    Mean Assessment_Score: 48.80
# Loaded bench_test_data_unique.json: 50 records
# Loaded bench_test_data_500.json: 500 records
# Loaded bench_test_data_1000.json: 1000 records
#
# Total test data collected: 1550 records
#    Mean Assessment_Score: 78.99

# %%
# Combine training and test data
df_combined = pd.concat([df_train_original, df_test_data], ignore_index=True)

# Create binary target: Pass (>=70) or Fail (<70)
def score_to_pass_fail(score):
    return 'Pass' if score >= 70 else 'Fail'

df_combined['Assessment_Result'] = df_combined['Assessment_Score'].apply(score_to_pass_fail)

# Show distribution
result_dist = df_combined['Assessment_Result'].value_counts()
print(f"\nDataset Distribution:")
print(f"   Pass (70-100): {result_dist.get('Pass', 0)} records ({result_dist.get('Pass', 0)/len(df_combined)*100:.1f}%)")
print(f"   Fail (0-69):   {result_dist.get('Fail', 0)} records ({result_dist.get('Fail', 0)/len(df_combined)*100:.1f}%)")
print(f"   Total:         {len(df_combined)} records")
# Out:
# Dataset Distribution:
#    Pass (70-100): 1936 records (68.0%)
#    Fail (0-69):   913 records (32.0%)
#    Total:         2849 records

# %%
# Feature engineering
df_binary_processed = df_combined.copy()

categorical_features_binary = ['Grade', 'Department', 'Primary_Skill', 'Secondary_Skill', 
                               'Course_Category', 'Delivery_Mode', 'Business_Priority', 
                               'Bench_Status', 'Learning_Style', 'Career_Goal', 'Training_Success', 'Training_Course_Name']

numerical_features_binary = ['Skill_Gap_Score', 'Availability_Hours_Per_Week', 'Performance_Rating', 'Duration_Hours', 'Completion_Percentage']

categorical_features_binary = [c for c in categorical_features_binary if c in df_binary_processed.columns]
numerical_features_binary = [c for c in numerical_features_binary if c in df_binary_processed.columns]

# Encode categorical features
label_encoders_binary = {}
for col in categorical_features_binary:
    le = LabelEncoder()
    df_binary_processed[col] = le.fit_transform(df_binary_processed[col].astype(str))
    label_encoders_binary[col] = le

# Encode target
le_target_binary = LabelEncoder()
df_binary_processed['Assessment_Result_Encoded'] = le_target_binary.fit_transform(df_binary_processed['Assessment_Result'])

# Scale numerical features
scaler_binary = StandardScaler()
df_binary_processed[numerical_features_binary] = scaler_binary.fit_transform(df_binary_processed[numerical_features_binary])

# Prepare features and target
X_binary = df_binary_processed[categorical_features_binary + numerical_features_binary]
y_binary = df_binary_processed['Assessment_Result_Encoded']

# Train-test split
X_train_binary, X_test_binary, y_train_binary, y_test_binary = train_test_split(
    X_binary, y_binary, test_size=0.2, random_state=42, stratify=y_binary
)

print(f"\nData Preparation Complete:")
print(f"   Total features: {len(categorical_features_binary)} categorical + {len(numerical_features_binary)} numerical")
print(f"   Training set: {len(X_train_binary)} records")
print(f"   Test set: {len(X_test_binary)} records")
# Out:
# Data Preparation Complete:
#    Total features: 12 categorical + 5 numerical
#    Training set: 2279 records
#    Test set: 570 records

# %%
print("Training Classification Models...\n")

# Train XGBoost
print("Training XGBoost Binary Classifier...")
xgb_binary = XGBClassifier(n_estimators=200, learning_rate=0.1, max_depth=8, random_state=42, verbosity=0)
xgb_binary.fit(X_train_binary, y_train_binary, verbose=False)
xgb_binary_pred = xgb_binary.predict(X_test_binary)
xgb_binary_acc = accuracy_score(y_test_binary, xgb_binary_pred)
print(f"XGBoost Accuracy: {xgb_binary_acc*100:.2f}%")

# Train Random Forest
print("Training Random Forest Classifier...")
rf_binary = RandomForestClassifier(n_estimators=200, max_depth=15, random_state=42, n_jobs=-1)
rf_binary.fit(X_train_binary, y_train_binary)
rf_binary_pred = rf_binary.predict(X_test_binary)
rf_binary_acc = accuracy_score(y_test_binary, rf_binary_pred)
print(f"Random Forest Accuracy: {rf_binary_acc*100:.2f}%")

# Train Logistic Regression
print("Training Logistic Regression...")
lr_binary = LogisticRegression(max_iter=1000, random_state=42, n_jobs=-1)
lr_binary.fit(X_train_binary, y_train_binary)
lr_binary_pred = lr_binary.predict(X_test_binary)
lr_binary_acc = accuracy_score(y_test_binary, lr_binary_pred)
print(f"Logistic Regression Accuracy: {lr_binary_acc*100:.2f}%")

# Select best model
best_binary_model = max([('XGBoost', xgb_binary, xgb_binary_pred), 
                         ('Random Forest', rf_binary, rf_binary_pred), 
                         ('Logistic Regression', lr_binary, lr_binary_pred)], 
                        key=lambda x: accuracy_score(y_test_binary, x[2]))

best_binary_name, best_binary_obj, best_binary_pred = best_binary_model

print(f"\n Best Model: {best_binary_name} ({accuracy_score(y_test_binary, best_binary_pred)*100:.2f}%)")
# Out:
# Training Classification Models...
#
# Training XGBoost Binary Classifier...
# XGBoost Accuracy: 88.07%
# Training Random Forest Classifier...
# Random Forest Accuracy: 87.02%
# Training Logistic Regression...
# Logistic Regression Accuracy: 76.14%
#
#  Best Model: XGBoost (88.07%)

# %%
# Detailed classification report
result_names = le_target_binary.classes_
y_test_result_names = [result_names[i] for i in y_test_binary]
best_result_names = [result_names[i] for i in best_binary_pred]

print("\nDETAILED CLASSIFICATION REPORT:")
print("="*70)
print(classification_report(y_test_result_names, best_result_names))

# Confusion matrix
cm = confusion_matrix(y_test_binary, best_binary_pred)
print("\nCONFUSION MATRIX:")
print("-"*50)
print(f"{'':15} {'Predicted Fail':<20} {'Predicted Pass':<20}")
print(f"{'Actual Fail':<15} {cm[0, 0]:<20} {cm[0, 1]:<20}")
print(f"{'Actual Pass':<15} {cm[1, 0]:<20} {cm[1, 1]:<20}")

# ROC-AUC
try:
    auc_score = roc_auc_score(y_test_binary, best_binary_obj.predict_proba(X_test_binary)[:, 1])
    print(f"\nROC-AUC Score: {auc_score:.4f}")
except:
    print("\nROC-AUC Score: N/A")
# Out:
# DETAILED CLASSIFICATION REPORT:
# ======================================================================
#               precision    recall  f1-score   support
#
#         Fail       0.80      0.84      0.82       183
#         Pass       0.92      0.90      0.91       387
#
#     accuracy                           0.88       570
#    macro avg       0.86      0.87      0.86       570
# weighted avg       0.88      0.88      0.88       570
#
#
# CONFUSION MATRIX:
# --------------------------------------------------
#                 Predicted Fail       Predicted Pass
# Actual Fail     153                  30
# Actual Pass     38                   349
#
# ROC-AUC Score: 0.9143

# %%
def predict_assessment_result(json_file, model, scaler, label_encs, le_tgt, cat_feats, num_feats):
    with open(json_file, 'r') as f:
        test_data = json.load(f)
    
    print(f"\nPREDICTIONS FOR: {json_file}")
    print(f"{'-'*130}")
    print(f"{'Record':<8} {'Actual Score':<15} {'Actual Status':<15} {'Predicted Status':<18} {'Predicted Range':<18} {'Match':<8}")
    print(f"{'-'*130}")
    
    correct = 0
    pass_count = 0
    pass_correct = 0
    fail_count = 0
    fail_correct = 0
    
    for idx, record in enumerate(test_data, 1):
        actual_score = record.get('Assessment_Score', 0)
        actual_result = 'Pass' if actual_score >= 70 else 'Fail'
        
        if actual_result == 'Pass':
            pass_count += 1
        else:
            fail_count += 1
        
        X_single = pd.DataFrame([record])
        
        for col in cat_feats:
            if col in X_single.columns:
                if col in label_encs:
                    try:
                        X_single[col] = label_encs[col].transform(X_single[col].astype(str))
                    except:
                        X_single[col] = 0
                else:
                    X_single[col] = 0
            else:
                X_single[col] = 0
        
        if len(X_single) > 0:
            X_single[num_feats] = scaler.transform(X_single[num_feats])
        
        X_single_feat = X_single[[col for col in cat_feats + num_feats if col in X_single.columns]]
        
        try:
            pred_encoded = model.predict(X_single_feat)[0]
            pred_result = le_tgt.classes_[pred_encoded]
        except:
            pred_result = 'Pass'
        
        pred_range = '70-100' if pred_result == 'Pass' else '0-69'
        
        is_match = "Yes" if pred_result == actual_result else "No"
        if pred_result == actual_result:
            correct += 1
            if actual_result == 'Pass':
                pass_correct += 1
            else:
                fail_correct += 1
        
        print(f"{idx:<8} {actual_score:<15.1f} {pred_range:<18} {actual_result:<15} {pred_result:<18} {is_match:<8}")
    
    accuracy = (correct / len(test_data)) * 100 if test_data else 0
    pass_accuracy = (pass_correct / pass_count * 100) if pass_count > 0 else 0
    fail_accuracy = (fail_correct / fail_count * 100) if fail_count > 0 else 0
    
    print(f"{'-'*130}")
    print(f"Total Records: {len(test_data)} | Overall Accuracy: {accuracy:.2f}% | Correct: {correct}/{len(test_data)}")
    print(f"Pass Accuracy: {pass_accuracy:.2f}% ({pass_correct}/{pass_count}) | Fail Accuracy: {fail_accuracy:.2f}% ({fail_correct}/{fail_count})\n")
    
    return accuracy, pass_accuracy, fail_accuracy

# %%
print(f"Model Type: {best_binary_name} Binary Classifier")
print(f"Threshold: Score >= 70 = Pass, Score < 70 = Fail")
print(f"Test Set Accuracy: {accuracy_score(y_test_binary, best_binary_pred)*100:.2f}%")
print(f"\nTo test a JSON file: predict_assessment_result('your_file.json', best_binary_obj, scaler_binary, label_encoders_binary, le_target_binary, categorical_features_binary, numerical_features_binary)")
# Out:
# Model Type: XGBoost Binary Classifier
# Threshold: Score >= 70 = Pass, Score < 70 = Fail
# Test Set Accuracy: 88.07%
#
# To test a JSON file: predict_assessment_result('your_file.json', best_binary_obj, scaler_binary, label_encoders_binary, le_target_binary, categorical_features_binary, numerical_features_binary)

# %%
predict_assessment_result('bench_test_data_1000.json', best_binary_obj, scaler_binary, label_encoders_binary, le_target_binary, categorical_features_binary, numerical_features_binary)
# Out:
# PREDICTIONS FOR: bench_test_data_1000.json
# ----------------------------------------------------------------------------------------------------------------------------------
# Record   Actual Score    Actual Status   Predicted Status   Predicted Range    Match
# ----------------------------------------------------------------------------------------------------------------------------------
# 1        83.0            70-100             Pass            Pass               Yes
# 2        90.0            70-100             Pass            Pass               Yes
# 3        91.0            70-100             Pass            Pass               Yes
# 4        82.0            70-100             Pass            Pass               Yes
# 5        83.0            70-100             Pass            Pass               Yes
# 6        0.0             0-69               Fail            Fail               Yes
# 7        80.0            70-100             Pass            Pass               Yes
# 8        91.0            70-100             Pass            Pass               Yes
# 9        76.0            70-100             Pass            Pass               Yes
# 10       82.0            70-100             Pass            Pass               Yes
# 11       91.0            70-100             Pass            Pass               Yes
# 12       85.0            70-100             Pass            Pass               Yes
# 13       88.0            70-100             Pass            Pass               Yes
# 14       90.0            70-100             Pass            Pass               Yes
# 15       88.0            70-100             Pass            Pass               Yes
# 16       75.0            70-100             Pass            Pass               Yes
# 17       78.0            70-100             Pass            Pass               Yes
# 18       88.0            70-100             Pass            Pass               Yes
# 19       74.0            70-100             Pass            Pass               Yes
# 20       75.0            70-100             Pass            Pass               Yes
# 21       75.0            70-100             Pass            Pass               Yes
# 22       80.0            70-100             Pass            Pass               Yes
# 23       85.0            70-100             Pass            Pass               Yes
# 24       92.0            70-100             Pass            Pass               Yes
# 25       86.0            70-100             Pass            Pass               Yes
# 26       90.0            70-100             Pass            Pass               Yes
# 27       78.0            70-100             Pass            Pass               Yes
# 28       83.0            70-100             Pass            Pass               Yes
# 29       82.0            70-100             Pass            Pass               Yes
# 30       75.0            70-100             Pass            Pass               Yes
# 31       90.0            70-100             Pass            Pass               Yes
# 32       88.0            70-100             Pass            Pass               Yes
# 33       90.0            70-100             Pass            Pass               Yes
# 34       91.0            70-100             Pass            Pass               Yes
# 35       89.0            70-100             Pass            Pass               Yes
# 36       85.0            70-100             Pass            Pass               Yes
# 37       84.0            70-100             Pass            Pass               Yes
# 38       91.0            70-100             Pass            Pass               Yes
# 39       91.0            70-100             Pass            Pass               Yes
# 40       91.0            70-100             Pass            Pass               Yes
# 41       80.0            70-100             Pass            Pass               Yes
# 42       79.0            70-100             Pass            Pass               Yes
# 43       83.0            70-100             Pass            Pass               Yes
# 44       85.0            70-100             Pass            Pass               Yes
# 45       77.0            70-100             Pass            Pass               Yes
# 46       82.0            70-100             Pass            Pass               Yes
# 47       81.0            70-100             Pass            Pass               Yes
# 48       81.0            70-100             Pass            Pass               Yes
# 49       84.0            70-100             Pass            Pass               Yes
# 50       79.0            70-100             Pass            Pass               Yes
# 51       89.0            70-100             Pass            Pass               Yes
# 52       74.0            70-100             Pass            Pass               Yes
# 53       80.0            70-100             Pass            Pass               Yes
# 54       88.0            70-100             Pass            Pass               Yes
# 55       77.0            70-100             Pass            Pass               Yes
# 56       0.0             0-69               Fail            Fail               Yes
# 57       74.0            70-100             Pass            Pass               Yes
# 58       74.0            70-100             Pass            Pass               Yes
# 59       77.0            70-100             Pass            Pass               Yes
# 60       77.0            70-100             Pass            Pass               Yes
# 61       75.0            70-100             Pass            Pass               Yes
# 62       76.0            70-100             Pass            Pass               Yes
# 63       82.0            70-100             Pass            Pass               Yes
# 64       88.0            70-100             Pass            Pass               Yes
# 65       76.0            70-100             Pass            Pass               Yes
# 66       80.0            70-100             Pass            Pass               Yes
# 67       80.0            70-100             Pass            Pass               Yes
# 68       83.0            70-100             Pass            Pass               Yes
# 69       0.0             0-69               Fail            Fail               Yes
# 70       84.0            70-100             Pass            Pass               Yes
# 71       88.0            70-100             Pass            Pass               Yes
# 72       84.0            70-100             Pass            Pass               Yes
# 73       76.0            70-100             Pass            Pass               Yes
# 74       91.0            70-100             Pass            Pass               Yes
# 75       80.0            70-100             Pass            Pass               Yes
# 76       85.0            70-100             Pass            Pass               Yes
# 77       79.0            70-100             Pass            Pass               Yes
# 78       90.0            70-100             Pass            Pass               Yes
# 79       89.0            70-100             Pass            Pass               Yes
# 80       74.0            70-100             Pass            Pass               Yes
# 81       89.0            70-100             Pass            Pass               Yes
# 82       84.0            70-100             Pass            Pass               Yes
# 83       86.0            70-100             Pass            Pass               Yes
# 84       88.0            70-100             Pass            Pass               Yes
# 85       78.0            70-100             Pass            Pass               Yes
# 86       0.0             0-69               Fail            Fail               Yes
# 87       88.0            70-100             Pass            Pass               Yes
# 88       75.0            70-100             Pass            Pass               Yes
# 89       75.0            70-100             Pass            Pass               Yes
# 90       77.0            70-100             Pass            Pass               Yes
# 91       85.0            70-100             Pass            Pass               Yes
# 92       0.0             0-69               Fail            Fail               Yes
# 93       78.0            70-100             Pass            Pass               Yes
# 94       78.0            70-100             Pass            Pass               Yes
# 95       83.0            70-100             Pass            Pass               Yes
# 96       91.0            70-100             Pass            Pass               Yes
# 97       82.0            70-100             Pass            Pass               Yes
# 98       92.0            70-100             Pass            Pass               Yes
# 99       89.0            70-100             Pass            Pass               Yes
# 100      81.0            70-100             Pass            Pass               Yes
# 101      79.0            70-100             Pass            Pass               Yes
# 102      92.0            70-100             Pass            Pass               Yes
# 103      0.0             70-100             Fail            Pass               No
# 104      75.0            70-100             Pass            Pass               Yes
# 105      78.0            70-100             Pass            Pass               Yes
# 106      76.0            70-100             Pass            Pass               Yes
# 107      90.0            70-100             Pass            Pass               Yes
# 108      80.0            70-100             Pass            Pass               Yes
# 109      85.0            70-100             Pass            Pass               Yes
# 110      80.0            70-100             Pass            Pass               Yes
# 111      78.0            70-100             Pass            Pass               Yes
# 112      76.0            70-100             Pass            Pass               Yes
# 113      87.0            70-100             Pass            Pass               Yes
# 114      0.0             0-69               Fail            Fail               Yes
# 115      79.0            70-100             Pass            Pass               Yes
# 116      79.0            70-100             Pass            Pass               Yes
# 117      88.0            70-100             Pass            Pass               Yes
# 118      80.0            70-100             Pass            Pass               Yes
# 119      75.0            70-100             Pass            Pass               Yes
# 120      86.0            70-100             Pass            Pass               Yes
# 121      79.0            70-100             Pass            Pass               Yes
# 122      83.0            70-100             Pass            Pass               Yes
# 123      79.0            70-100             Pass            Pass               Yes
# 124      82.0            70-100             Pass            Pass               Yes
# 125      87.0            70-100             Pass            Pass               Yes
# 126      78.0            70-100             Pass            Pass               Yes
# 127      86.0            70-100             Pass            Pass               Yes
# 128      0.0             0-69               Fail            Fail               Yes
# 129      76.0            70-100             Pass            Pass               Yes
# 130      92.0            70-100             Pass            Pass               Yes
# 131      75.0            70-100             Pass            Pass               Yes
# 132      85.0            70-100             Pass            Pass               Yes
# 133      80.0            70-100             Pass            Pass               Yes
# 134      78.0            70-100             Pass            Pass               Yes
# 135      84.0            70-100             Pass            Pass               Yes
# 136      83.0            70-100             Pass            Pass               Yes
# 137      79.0            70-100             Pass            Pass               Yes
# 138      92.0            70-100             Pass            Pass               Yes
# 139      79.0            70-100             Pass            Pass               Yes
# 140      80.0            70-100             Pass            Pass               Yes
# 141      75.0            70-100             Pass            Pass               Yes
# 142      90.0            70-100             Pass            Pass               Yes
# 143      86.0            70-100             Pass            Pass               Yes
# 144      83.0            70-100             Pass            Pass               Yes
# 145      74.0            70-100             Pass            Pass               Yes
# 146      82.0            70-100             Pass            Pass               Yes
# 147      89.0            70-100             Pass            Pass               Yes
# 148      82.0            70-100             Pass            Pass               Yes
# 149      77.0            70-100             Pass            Pass               Yes
# 150      79.0            70-100             Pass            Pass               Yes
# 151      89.0            70-100             Pass            Pass               Yes
# 152      0.0             0-69               Fail            Fail               Yes
# 153      77.0            70-100             Pass            Pass               Yes
# 154      74.0            70-100             Pass            Pass               Yes
# 155      89.0            70-100             Pass            Pass               Yes
# 156      84.0            70-100             Pass            Pass               Yes
# 157      92.0            70-100             Pass            Pass               Yes
# 158      91.0            70-100             Pass            Pass               Yes
# 159      86.0            70-100             Pass            Pass               Yes
# 160      87.0            70-100             Pass            Pass               Yes
# 161      75.0            70-100             Pass            Pass               Yes
# 162      90.0            70-100             Pass            Pass               Yes
# 163      83.0            70-100             Pass            Pass               Yes
# 164      74.0            70-100             Pass            Pass               Yes
# 165      89.0            70-100             Pass            Pass               Yes
# 166      87.0            70-100             Pass            Pass               Yes
# 167      89.0            70-100             Pass            Pass               Yes
# 168      82.0            70-100             Pass            Pass               Yes
# 169      74.0            70-100             Pass            Pass               Yes
# 170      85.0            70-100             Pass            Pass               Yes
# 171      76.0            70-100             Pass            Pass               Yes
# 172      83.0            70-100             Pass            Pass               Yes
# 173      74.0            70-100             Pass            Pass               Yes
# 174      83.0            70-100             Pass            Pass               Yes
# 175      74.0            70-100             Pass            Pass               Yes
# 176      74.0            70-100             Pass            Pass               Yes
# 177      86.0            70-100             Pass            Pass               Yes
# 178      87.0            70-100             Pass            Pass               Yes
# 179      84.0            70-100             Pass            Pass               Yes
# 180      81.0            70-100             Pass            Pass               Yes
# 181      76.0            70-100             Pass            Pass               Yes
# 182      87.0            70-100             Pass            Pass               Yes
# 183      77.0            70-100             Pass            Pass               Yes
# 184      92.0            70-100             Pass            Pass               Yes
# 185      76.0            70-100             Pass            Pass               Yes
# 186      89.0            70-100             Pass            Pass               Yes
# 187      90.0            70-100             Pass            Pass               Yes
# 188      77.0            70-100             Pass            Pass               Yes
# 189      74.0            70-100             Pass            Pass               Yes
# 190      87.0            70-100             Pass            Pass               Yes
# 191      0.0             0-69               Fail            Fail               Yes
# 192      90.0            70-100             Pass            Pass               Yes
# 193      74.0            70-100             Pass            Pass               Yes
# 194      92.0            70-100             Pass            Pass               Yes
# 195      88.0            70-100             Pass            Pass               Yes
# 196      92.0            70-100             Pass            Pass               Yes
# 197      84.0            70-100             Pass            Pass               Yes
# 198      76.0            70-100             Pass            Pass               Yes
# 199      91.0            70-100             Pass            Pass               Yes
# 200      78.0            70-100             Pass            Pass               Yes
# 201      74.0            70-100             Pass            Pass               Yes
# 202      75.0            70-100             Pass            Pass               Yes
# 203      0.0             0-69               Fail            Fail               Yes
# 204      82.0            70-100             Pass            Pass               Yes
# 205      74.0            70-100             Pass            Pass               Yes
# 206      84.0            70-100             Pass            Pass               Yes
# 207      79.0            70-100             Pass            Pass               Yes
# 208      84.0            70-100             Pass            Pass               Yes
# 209      92.0            70-100             Pass            Pass               Yes
# 210      84.0            70-100             Pass            Pass               Yes
# 211      74.0            70-100             Pass            Pass               Yes
# 212      84.0            70-100             Pass            Pass               Yes
# 213      79.0            70-100             Pass            Pass               Yes
# 214      81.0            70-100             Pass            Pass               Yes
# 215      89.0            70-100             Pass            Pass               Yes
# 216      75.0            70-100             Pass            Pass               Yes
# 217      89.0            70-100             Pass            Pass               Yes
# 218      90.0            70-100             Pass            Pass               Yes
# 219      89.0            70-100             Pass            Pass               Yes
# 220      82.0            70-100             Pass            Pass               Yes
# 221      77.0            70-100             Pass            Pass               Yes
# 222      80.0            70-100             Pass            Pass               Yes
# 223      86.0            70-100             Pass            Pass               Yes
# 224      84.0            70-100             Pass            Pass               Yes
# 225      89.0            70-100             Pass            Pass               Yes
# 226      84.0            70-100             Pass            Pass               Yes
# 227      87.0            70-100             Pass            Pass               Yes
# 228      81.0            70-100             Pass            Pass               Yes
# 229      79.0            70-100             Pass            Pass               Yes
# 230      84.0            70-100             Pass            Pass               Yes
# 231      0.0             0-69               Fail            Fail               Yes
# 232      87.0            70-100             Pass            Pass               Yes
# 233      77.0            70-100             Pass            Pass               Yes
# 234      75.0            70-100             Pass            Pass               Yes
# 235      82.0            70-100             Pass            Pass               Yes
# 236      87.0            70-100             Pass            Pass               Yes
# 237      85.0            70-100             Pass            Pass               Yes
# 238      76.0            70-100             Pass            Pass               Yes
# 239      87.0            70-100             Pass            Pass               Yes
# 240      88.0            70-100             Pass            Pass               Yes
# 241      84.0            70-100             Pass            Pass               Yes
# 242      83.0            70-100             Pass            Pass               Yes
# 243      85.0            70-100             Pass            Pass               Yes
# 244      75.0            70-100             Pass            Pass               Yes
# 245      85.0            70-100             Pass            Pass               Yes
# 246      80.0            70-100             Pass            Pass               Yes
# 247      88.0            70-100             Pass            Pass               Yes
# 248      84.0            70-100             Pass            Pass               Yes
# 249      90.0            70-100             Pass            Pass               Yes
# 250      83.0            70-100             Pass            Pass               Yes
# 251      0.0             0-69               Fail            Fail               Yes
# 252      78.0            70-100             Pass            Pass               Yes
# 253      86.0            70-100             Pass            Pass               Yes
# 254      88.0            70-100             Pass            Pass               Yes
# 255      88.0            70-100             Pass            Pass               Yes
# 256      91.0            70-100             Pass            Pass               Yes
# 257      75.0            70-100             Pass            Pass               Yes
# 258      74.0            70-100             Pass            Pass               Yes
# 259      88.0            70-100             Pass            Pass               Yes
# 260      78.0            70-100             Pass            Pass               Yes
# 261      90.0            70-100             Pass            Pass               Yes
# 262      89.0            70-100             Pass            Pass               Yes
# 263      74.0            70-100             Pass            Pass               Yes
# 264      77.0            70-100             Pass            Pass               Yes
# 265      75.0            70-100             Pass            Pass               Yes
# 266      79.0            70-100             Pass            Pass               Yes
# 267      82.0            70-100             Pass            Pass               Yes
# 268      0.0             0-69               Fail            Fail               Yes
# 269      79.0            70-100             Pass            Pass               Yes
# 270      82.0            70-100             Pass            Pass               Yes
# 271      91.0            70-100             Pass            Pass               Yes
# 272      83.0            70-100             Pass            Pass               Yes
# 273      76.0            70-100             Pass            Pass               Yes
# 274      75.0            70-100             Pass            Pass               Yes
# 275      83.0            70-100             Pass            Pass               Yes
# 276      76.0            70-100             Pass            Pass               Yes
# 277      83.0            70-100             Pass            Pass               Yes
# 278      87.0            70-100             Pass            Pass               Yes
# 279      80.0            70-100             Pass            Pass               Yes
# 280      88.0            70-100             Pass            Pass               Yes
# 281      78.0            70-100             Pass            Pass               Yes
# 282      92.0            70-100             Pass            Pass               Yes
# 283      76.0            70-100             Pass            Pass               Yes
# 284      76.0            70-100             Pass            Pass               Yes
# 285      81.0            70-100             Pass            Pass               Yes
# 286      83.0            70-100             Pass            Pass               Yes
# 287      76.0            70-100             Pass            Pass               Yes
# 288      76.0            70-100             Pass            Pass               Yes
# 289      83.0            70-100             Pass            Pass               Yes
# 290      91.0            70-100             Pass            Pass               Yes
# 291      77.0            70-100             Pass            Pass               Yes
# 292      90.0            70-100             Pass            Pass               Yes
# 293      77.0            70-100             Pass            Pass               Yes
# 294      85.0            70-100             Pass            Pass               Yes
# 295      87.0            70-100             Pass            Pass               Yes
# 296      86.0            70-100             Pass            Pass               Yes
# 297      89.0            70-100             Pass            Pass               Yes
# 298      91.0            70-100             Pass            Pass               Yes
# 299      88.0            70-100             Pass            Pass               Yes
# 300      86.0            70-100             Pass            Pass               Yes
# 301      91.0            70-100             Pass            Pass               Yes
# 302      74.0            70-100             Pass            Pass               Yes
# 303      74.0            70-100             Pass            Pass               Yes
# 304      81.0            70-100             Pass            Pass               Yes
# 305      78.0            70-100             Pass            Pass               Yes
# 306      0.0             0-69               Fail            Fail               Yes
# 307      83.0            70-100             Pass            Pass               Yes
# 308      74.0            70-100             Pass            Pass               Yes
# 309      82.0            70-100             Pass            Pass               Yes
# 310      81.0            70-100             Pass            Pass               Yes
# 311      91.0            70-100             Pass            Pass               Yes
# 312      89.0            70-100             Pass            Pass               Yes
# 313      76.0            70-100             Pass            Pass               Yes
# 314      86.0            70-100             Pass            Pass               Yes
# 315      87.0            70-100             Pass            Pass               Yes
# 316      76.0            70-100             Pass            Pass               Yes
# 317      0.0             0-69               Fail            Fail               Yes
# 318      90.0            70-100             Pass            Pass               Yes
# 319      79.0            70-100             Pass            Pass               Yes
# 320      90.0            70-100             Pass            Pass               Yes
# 321      80.0            70-100             Pass            Pass               Yes
# 322      83.0            70-100             Pass            Pass               Yes
# 323      76.0            70-100             Pass            Pass               Yes
# 324      83.0            70-100             Pass            Pass               Yes
# 325      83.0            70-100             Pass            Pass               Yes
# 326      89.0            70-100             Pass            Pass               Yes
# 327      83.0            70-100             Pass            Pass               Yes
# 328      88.0            70-100             Pass            Pass               Yes
# 329      84.0            70-100             Pass            Pass               Yes
# 330      90.0            70-100             Pass            Pass               Yes
# 331      87.0            70-100             Pass            Pass               Yes
# 332      84.0            70-100             Pass            Pass               Yes
# 333      0.0             0-69               Fail            Fail               Yes
# 334      0.0             0-69               Fail            Fail               Yes
# 335      77.0            70-100             Pass            Pass               Yes
# 336      84.0            70-100             Pass            Pass               Yes
# 337      85.0            70-100             Pass            Pass               Yes
# 338      89.0            70-100             Pass            Pass               Yes
# 339      92.0            70-100             Pass            Pass               Yes
# 340      74.0            70-100             Pass            Pass               Yes
# 341      77.0            70-100             Pass            Pass               Yes
# 342      90.0            70-100             Pass            Pass               Yes
# 343      77.0            70-100             Pass            Pass               Yes
# 344      90.0            70-100             Pass            Pass               Yes
# 345      74.0            70-100             Pass            Pass               Yes
# 346      80.0            70-100             Pass            Pass               Yes
# 347      84.0            70-100             Pass            Pass               Yes
# 348      85.0            70-100             Pass            Pass               Yes
# 349      79.0            70-100             Pass            Pass               Yes
# 350      83.0            70-100             Pass            Pass               Yes
# 351      77.0            70-100             Pass            Pass               Yes
# 352      79.0            70-100             Pass            Pass               Yes
# 353      90.0            70-100             Pass            Pass               Yes
# 354      74.0            70-100             Pass            Pass               Yes
# 355      90.0            70-100             Pass            Pass               Yes
# 356      91.0            70-100             Pass            Pass               Yes
# 357      76.0            70-100             Pass            Pass               Yes
# 358      75.0            70-100             Pass            Pass               Yes
# 359      82.0            70-100             Pass            Pass               Yes
# 360      88.0            70-100             Pass            Pass               Yes
# 361      76.0            70-100             Pass            Pass               Yes
# 362      77.0            70-100             Pass            Pass               Yes
# 363      87.0            70-100             Pass            Pass               Yes
# 364      74.0            70-100             Pass            Pass               Yes
# 365      91.0            70-100             Pass            Pass               Yes
# 366      0.0             0-69               Fail            Fail               Yes
# 367      84.0            70-100             Pass            Pass               Yes
# 368      80.0            70-100             Pass            Pass               Yes
# 369      85.0            70-100             Pass            Pass               Yes
# 370      92.0            70-100             Pass            Pass               Yes
# 371      88.0            70-100             Pass            Pass               Yes
# 372      78.0            70-100             Pass            Pass               Yes
# 373      92.0            70-100             Pass            Pass               Yes
# 374      90.0            70-100             Pass            Pass               Yes
# 375      90.0            70-100             Pass            Pass               Yes
# 376      90.0            70-100             Pass            Pass               Yes
# 377      85.0            70-100             Pass            Pass               Yes
# 378      76.0            70-100             Pass            Pass               Yes
# 379      76.0            70-100             Pass            Pass               Yes
# 380      84.0            70-100             Pass            Pass               Yes
# 381      77.0            70-100             Pass            Pass               Yes
# 382      85.0            70-100             Pass            Pass               Yes
# 383      84.0            70-100             Pass            Pass               Yes
# 384      91.0            70-100             Pass            Pass               Yes
# 385      76.0            70-100             Pass            Pass               Yes
# 386      91.0            70-100             Pass            Pass               Yes
# 387      88.0            70-100             Pass            Pass               Yes
# 388      92.0            70-100             Pass            Pass               Yes
# 389      88.0            70-100             Pass            Pass               Yes
# 390      90.0            70-100             Pass            Pass               Yes
# 391      84.0            70-100             Pass            Pass               Yes
# 392      88.0            70-100             Pass            Pass               Yes
# 393      91.0            70-100             Pass            Pass               Yes
# 394      80.0            70-100             Pass            Pass               Yes
# 395      92.0            70-100             Pass            Pass               Yes
# 396      81.0            70-100             Pass            Pass               Yes
# 397      87.0            70-100             Pass            Pass               Yes
# 398      83.0            70-100             Pass            Pass               Yes
# 399      77.0            70-100             Pass            Pass               Yes
# 400      86.0            70-100             Pass            Pass               Yes
# 401      77.0            70-100             Pass            Pass               Yes
# 402      79.0            70-100             Pass            Pass               Yes
# 403      90.0            70-100             Pass            Pass               Yes
# 404      81.0            70-100             Pass            Pass               Yes
# 405      82.0            70-100             Pass            Pass               Yes
# 406      76.0            70-100             Pass            Pass               Yes
# 407      0.0             0-69               Fail            Fail               Yes
# 408      82.0            70-100             Pass            Pass               Yes
# 409      74.0            70-100             Pass            Pass               Yes
# 410      91.0            70-100             Pass            Pass               Yes
# 411      75.0            70-100             Pass            Pass               Yes
# 412      79.0            70-100             Pass            Pass               Yes
# 413      87.0            70-100             Pass            Pass               Yes
# 414      91.0            70-100             Pass            Pass               Yes
# 415      82.0            70-100             Pass            Pass               Yes
# 416      78.0            70-100             Pass            Pass               Yes
# 417      79.0            70-100             Pass            Pass               Yes
# 418      82.0            70-100             Pass            Pass               Yes
# 419      90.0            70-100             Pass            Pass               Yes
# 420      82.0            70-100             Pass            Pass               Yes
# 421      85.0            70-100             Pass            Pass               Yes
# 422      81.0            70-100             Pass            Pass               Yes
# 423      84.0            70-100             Pass            Pass               Yes
# 424      0.0             0-69               Fail            Fail               Yes
# 425      83.0            70-100             Pass            Pass               Yes
# 426      84.0            70-100             Pass            Pass               Yes
# 427      92.0            70-100             Pass            Pass               Yes
# 428      83.0            70-100             Pass            Pass               Yes
# 429      82.0            70-100             Pass            Pass               Yes
# 430      84.0            70-100             Pass            Pass               Yes
# 431      81.0            70-100             Pass            Pass               Yes
# 432      79.0            70-100             Pass            Pass               Yes
# 433      74.0            70-100             Pass            Pass               Yes
# 434      85.0            70-100             Pass            Pass               Yes
# 435      88.0            70-100             Pass            Pass               Yes
# 436      92.0            70-100             Pass            Pass               Yes
# 437      89.0            70-100             Pass            Pass               Yes
# 438      79.0            70-100             Pass            Pass               Yes
# 439      87.0            70-100             Pass            Pass               Yes
# 440      74.0            70-100             Pass            Pass               Yes
# 441      86.0            70-100             Pass            Pass               Yes
# 442      81.0            70-100             Pass            Pass               Yes
# 443      92.0            70-100             Pass            Pass               Yes
# 444      83.0            70-100             Pass            Pass               Yes
# 445      91.0            70-100             Pass            Pass               Yes
# 446      85.0            70-100             Pass            Pass               Yes
# 447      90.0            70-100             Pass            Pass               Yes
# 448      86.0            70-100             Pass            Pass               Yes
# 449      91.0            70-100             Pass            Pass               Yes
# 450      83.0            70-100             Pass            Pass               Yes
# 451      75.0            70-100             Pass            Pass               Yes
# 452      91.0            70-100             Pass            Pass               Yes
# 453      91.0            70-100             Pass            Pass               Yes
# 454      87.0            70-100             Pass            Pass               Yes
# 455      82.0            70-100             Pass            Pass               Yes
# 456      75.0            70-100             Pass            Pass               Yes
# 457      84.0            70-100             Pass            Pass               Yes
# 458      85.0            70-100             Pass            Pass               Yes
# 459      89.0            70-100             Pass            Pass               Yes
# 460      91.0            70-100             Pass            Pass               Yes
# 461      88.0            70-100             Pass            Pass               Yes
# 462      82.0            70-100             Pass            Pass               Yes
# 463      81.0            70-100             Pass            Pass               Yes
# 464      84.0            70-100             Pass            Pass               Yes
# 465      80.0            70-100             Pass            Pass               Yes
# 466      88.0            70-100             Pass            Pass               Yes
# 467      83.0            70-100             Pass            Pass               Yes
# 468      89.0            70-100             Pass            Pass               Yes
# 469      83.0            70-100             Pass            Pass               Yes
# 470      89.0            70-100             Pass            Pass               Yes
# 471      0.0             0-69               Fail            Fail               Yes
# 472      79.0            70-100             Pass            Pass               Yes
# 473      84.0            70-100             Pass            Pass               Yes
# 474      81.0            70-100             Pass            Pass               Yes
# 475      92.0            70-100             Pass            Pass               Yes
# 476      78.0            70-100             Pass            Pass               Yes
# 477      85.0            70-100             Pass            Pass               Yes
# 478      87.0            70-100             Pass            Pass               Yes
# 479      75.0            70-100             Pass            Pass               Yes
# 480      81.0            70-100             Pass            Pass               Yes
# 481      81.0            70-100             Pass            Pass               Yes
# 482      87.0            70-100             Pass            Pass               Yes
# 483      88.0            70-100             Pass            Pass               Yes
# 484      75.0            70-100             Pass            Pass               Yes
# 485      76.0            70-100             Pass            Pass               Yes
# 486      82.0            70-100             Pass            Pass               Yes
# 487      76.0            70-100             Pass            Pass               Yes
# 488      74.0            70-100             Pass            Pass               Yes
# 489      76.0            70-100             Pass            Pass               Yes
# 490      88.0            70-100             Pass            Pass               Yes
# 491      85.0            70-100             Pass            Pass               Yes
# 492      89.0            70-100             Pass            Pass               Yes
# 493      81.0            70-100             Pass            Pass               Yes
# 494      80.0            70-100             Pass            Pass               Yes
# 495      74.0            70-100             Pass            Pass               Yes
# 496      81.0            70-100             Pass            Pass               Yes
# 497      74.0            70-100             Pass            Pass               Yes
# 498      88.0            70-100             Pass            Pass               Yes
# 499      85.0            70-100             Pass            Pass               Yes
# 500      82.0            70-100             Pass            Pass               Yes
# 501      76.0            70-100             Pass            Pass               Yes
# 502      83.0            70-100             Pass            Pass               Yes
# 503      84.0            70-100             Pass            Pass               Yes
# 504      82.0            70-100             Pass            Pass               Yes
# 505      79.0            70-100             Pass            Pass               Yes
# 506      82.0            70-100             Pass            Pass               Yes
# 507      79.0            70-100             Pass            Pass               Yes
# 508      84.0            70-100             Pass            Pass               Yes
# 509      84.0            70-100             Pass            Pass               Yes
# 510      92.0            70-100             Pass            Pass               Yes
# 511      81.0            70-100             Pass            Pass               Yes
# 512      78.0            70-100             Pass            Pass               Yes
# 513      82.0            70-100             Pass            Pass               Yes
# 514      80.0            70-100             Pass            Pass               Yes
# 515      83.0            70-100             Pass            Pass               Yes
# 516      87.0            70-100             Pass            Pass               Yes
# 517      81.0            70-100             Pass            Pass               Yes
# 518      86.0            70-100             Pass            Pass               Yes
# 519      0.0             0-69               Fail            Fail               Yes
# 520      82.0            70-100             Pass            Pass               Yes
# 521      77.0            70-100             Pass            Pass               Yes
# 522      83.0            70-100             Pass            Pass               Yes
# 523      81.0            70-100             Pass            Pass               Yes
# 524      76.0            70-100             Pass            Pass               Yes
# 525      87.0            70-100             Pass            Pass               Yes
# 526      83.0            70-100             Pass            Pass               Yes
# 527      80.0            70-100             Pass            Pass               Yes
# 528      79.0            70-100             Pass            Pass               Yes
# 529      88.0            70-100             Pass            Pass               Yes
# 530      86.0            70-100             Pass            Pass               Yes
# 531      75.0            70-100             Pass            Pass               Yes
# 532      76.0            70-100             Pass            Pass               Yes
# 533      80.0            70-100             Pass            Pass               Yes
# 534      92.0            70-100             Pass            Pass               Yes
# 535      82.0            70-100             Pass            Pass               Yes
# 536      90.0            70-100             Pass            Pass               Yes
# 537      89.0            70-100             Pass            Pass               Yes
# 538      92.0            70-100             Pass            Pass               Yes
# 539      86.0            70-100             Pass            Pass               Yes
# 540      85.0            70-100             Pass            Pass               Yes
# ...
# 823      76.0            70-100             Pass            Pass               Yes
# 824      81.0            70-100             Pass            Pass               Yes
# 825      80.0            70-100             Pass            Pass               Yes
# 826      77.0            70-100             Pass            Pass               Yes
# 827      82.0            70-100             Pass            Pass               Yes
# 828      76.0            70-100             Pass            Pass               Yes
# 829      75.0            70-100             Pass            Pass               Yes
# 830      82.0            70-100             Pass            Pass               Yes
# 831      82.0            70-100             Pass            Pass               Yes
# 832      79.0            70-100             Pass            Pass               Yes
# 833      0.0             70-100             Fail            Pass               No
# 834      74.0            70-100             Pass            Pass               Yes
# 835      76.0            70-100             Pass            Pass               Yes
# 836      89.0            70-100             Pass            Pass               Yes
# 837      82.0            70-100             Pass            Pass               Yes
# 838      79.0            70-100             Pass            Pass               Yes
# 839      89.0            70-100             Pass            Pass               Yes
# 840      75.0            70-100             Pass            Pass               Yes
# 841      92.0            70-100             Pass            Pass               Yes
# 842      89.0            70-100             Pass            Pass               Yes
# 843      78.0            70-100             Pass            Pass               Yes
# 844      88.0            70-100             Pass            Pass               Yes
# 845      78.0            70-100             Pass            Pass               Yes
# 846      81.0            70-100             Pass            Pass               Yes
# 847      80.0            70-100             Pass            Pass               Yes
# 848      84.0            70-100             Pass            Pass               Yes
# 849      79.0            70-100             Pass            Pass               Yes
# 850      91.0            70-100             Pass            Pass               Yes
# 851      77.0            70-100             Pass            Pass               Yes
# 852      81.0            70-100             Pass            Pass               Yes
# 853      88.0            70-100             Pass            Pass               Yes
# 854      76.0            70-100             Pass            Pass               Yes
# 855      78.0            70-100             Pass            Pass               Yes
# 856      79.0            70-100             Pass            Pass               Yes
# 857      83.0            70-100             Pass            Pass               Yes
# 858      74.0            70-100             Pass            Pass               Yes
# 859      87.0            70-100             Pass            Pass               Yes
# 860      75.0            70-100             Pass            Pass               Yes
# 861      82.0            70-100             Pass            Pass               Yes
# 862      91.0            70-100             Pass            Pass               Yes
# 863      74.0            70-100             Pass            Pass               Yes
# 864      79.0            70-100             Pass            Pass               Yes
# 865      75.0            70-100             Pass            Pass               Yes
# 866      76.0            70-100             Pass            Pass               Yes
# 867      81.0            70-100             Pass            Pass               Yes
# 868      87.0            70-100             Pass            Pass               Yes
# 869      82.0            70-100             Pass            Pass               Yes
# 870      78.0            70-100             Pass            Pass               Yes
# 871      78.0            70-100             Pass            Pass               Yes
# 872      80.0            70-100             Pass            Pass               Yes
# 873      85.0            70-100             Pass            Pass               Yes
# 874      91.0            70-100             Pass            Pass               Yes
# 875      85.0            70-100             Pass            Pass               Yes
# 876      91.0            70-100             Pass            Pass               Yes
# 877      92.0            70-100             Pass            Pass               Yes
# 878      83.0            70-100             Pass            Pass               Yes
# 879      75.0            70-100             Pass            Pass               Yes
# 880      79.0            70-100             Pass            Pass               Yes
# 881      90.0            70-100             Pass            Pass               Yes
# 882      74.0            70-100             Pass            Pass               Yes
# 883      0.0             0-69               Fail            Fail               Yes
# 884      77.0            70-100             Pass            Pass               Yes
# 885      91.0            70-100             Pass            Pass               Yes
# 886      76.0            70-100             Pass            Pass               Yes
# 887      86.0            70-100             Pass            Pass               Yes
# 888      91.0            70-100             Pass            Pass               Yes
# 889      88.0            70-100             Pass            Pass               Yes
# 890      85.0            70-100             Pass            Pass               Yes
# 891      0.0             0-69               Fail            Fail               Yes
# 892      74.0            70-100             Pass            Pass               Yes
# 893      85.0            70-100             Pass            Pass               Yes
# 894      92.0            70-100             Pass            Pass               Yes
# 895      85.0            70-100             Pass            Pass               Yes
# 896      89.0            70-100             Pass            Pass               Yes
# 897      79.0            70-100             Pass            Pass               Yes
# 898      75.0            70-100             Pass            Pass               Yes
# 899      0.0             0-69               Fail            Fail               Yes
# 900      89.0            70-100             Pass            Pass               Yes
# 901      77.0            70-100             Pass            Pass               Yes
# 902      76.0            70-100             Pass            Pass               Yes
# 903      89.0            70-100             Pass            Pass               Yes
# 904      85.0            70-100             Pass            Pass               Yes
# 905      77.0            70-100             Pass            Pass               Yes
# 906      90.0            70-100             Pass            Pass               Yes
# 907      77.0            70-100             Pass            Pass               Yes
# 908      89.0            70-100             Pass            Pass               Yes
# 909      82.0            70-100             Pass            Pass               Yes
# 910      82.0            70-100             Pass            Pass               Yes
# 911      79.0            70-100             Pass            Pass               Yes
# 912      78.0            70-100             Pass            Pass               Yes
# 913      86.0            70-100             Pass            Pass               Yes
# 914      76.0            70-100             Pass            Pass               Yes
# 915      0.0             70-100             Fail            Pass               No
# 916      89.0            70-100             Pass            Pass               Yes
# 917      83.0            70-100             Pass            Pass               Yes
# 918      79.0            70-100             Pass            Pass               Yes
# 919      85.0            70-100             Pass            Pass               Yes
# 920      0.0             0-69               Fail            Fail               Yes
# 921      91.0            70-100             Pass            Pass               Yes
# 922      74.0            70-100             Pass            Pass               Yes
# 923      89.0            70-100             Pass            Pass               Yes
# 924      90.0            70-100             Pass            Pass               Yes
# 925      82.0            70-100             Pass            Pass               Yes
# 926      86.0            70-100             Pass            Pass               Yes
# 927      90.0            70-100             Pass            Pass               Yes
# 928      74.0            70-100             Pass            Pass               Yes
# 929      77.0            70-100             Pass            Pass               Yes
# 930      0.0             0-69               Fail            Fail               Yes
# 931      83.0            70-100             Pass            Pass               Yes
# 932      90.0            70-100             Pass            Pass               Yes
# 933      82.0            70-100             Pass            Pass               Yes
# 934      88.0            70-100             Pass            Pass               Yes
# 935      90.0            70-100             Pass            Pass               Yes
# 936      81.0            70-100             Pass            Pass               Yes
# 937      84.0            70-100             Pass            Pass               Yes
# 938      75.0            70-100             Pass            Pass               Yes
# 939      89.0            70-100             Pass            Pass               Yes
# 940      85.0            70-100             Pass            Pass               Yes
# 941      88.0            70-100             Pass            Pass               Yes
# 942      82.0            70-100             Pass            Pass               Yes
# 943      79.0            70-100             Pass            Pass               Yes
# 944      75.0            70-100             Pass            Pass               Yes
# 945      83.0            70-100             Pass            Pass               Yes
# 946      85.0            70-100             Pass            Pass               Yes
# 947      83.0            70-100             Pass            Pass               Yes
# 948      88.0            70-100             Pass            Pass               Yes
# 949      77.0            70-100             Pass            Pass               Yes
# 950      76.0            70-100             Pass            Pass               Yes
# 951      83.0            70-100             Pass            Pass               Yes
# 952      80.0            70-100             Pass            Pass               Yes
# 953      76.0            70-100             Pass            Pass               Yes
# 954      74.0            70-100             Pass            Pass               Yes
# 955      77.0            70-100             Pass            Pass               Yes
# 956      89.0            70-100             Pass            Pass               Yes
# 957      0.0             0-69               Fail            Fail               Yes
# 958      81.0            70-100             Pass            Pass               Yes
# 959      86.0            70-100             Pass            Pass               Yes
# 960      78.0            70-100             Pass            Pass               Yes
# 961      84.0            70-100             Pass            Pass               Yes
# 962      76.0            70-100             Pass            Pass               Yes
# 963      75.0            70-100             Pass            Pass               Yes
# 964      81.0            70-100             Pass            Pass               Yes
# 965      83.0            70-100             Pass            Pass               Yes
# 966      90.0            70-100             Pass            Pass               Yes
# 967      74.0            70-100             Pass            Pass               Yes
# 968      86.0            70-100             Pass            Pass               Yes
# 969      78.0            70-100             Pass            Pass               Yes
# 970      92.0            70-100             Pass            Pass               Yes
# 971      92.0            70-100             Pass            Pass               Yes
# 972      90.0            70-100             Pass            Pass               Yes
# 973      86.0            70-100             Pass            Pass               Yes
# 974      88.0            70-100             Pass            Pass               Yes
# 975      74.0            70-100             Pass            Pass               Yes
# 976      80.0            70-100             Pass            Pass               Yes
# 977      92.0            70-100             Pass            Pass               Yes
# 978      80.0            70-100             Pass            Pass               Yes
# 979      78.0            70-100             Pass            Pass               Yes
# 980      86.0            70-100             Pass            Pass               Yes
# 981      84.0            70-100             Pass            Pass               Yes
# 982      86.0            70-100             Pass            Pass               Yes
# 983      80.0            70-100             Pass            Pass               Yes
# 984      91.0            70-100             Pass            Pass               Yes
# 985      81.0            70-100             Pass            Pass               Yes
# 986      77.0            70-100             Pass            Pass               Yes
# 987      77.0            70-100             Pass            Pass               Yes
# 988      90.0            70-100             Pass            Pass               Yes
# 989      86.0            70-100             Pass            Pass               Yes
# 990      79.0            70-100             Pass            Pass               Yes
# 991      82.0            70-100             Pass            Pass               Yes
# 992      85.0            70-100             Pass            Pass               Yes
# 993      84.0            70-100             Pass            Pass               Yes
# 994      74.0            70-100             Pass            Pass               Yes
# 995      89.0            70-100             Pass            Pass               Yes
# 996      90.0            70-100             Pass            Pass               Yes
# 997      80.0            70-100             Pass            Pass               Yes
# 998      87.0            70-100             Pass            Pass               Yes
# 999      90.0            70-100             Pass            Pass               Yes
# 1000     90.0            70-100             Pass            Pass               Yes
# ----------------------------------------------------------------------------------------------------------------------------------
# Total Records: 1000 | Overall Accuracy: 99.40% | Correct: 994/1000
# Pass Accuracy: 100.00% (953/953) | Fail Accuracy: 87.23% (41/47)
# (99.4, 100.0, 87.2340425531915)
